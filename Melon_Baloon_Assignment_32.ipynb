# %%
import random
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
N = 1000
std = 3

melon = pd.DataFrame({
    'length': np.random.normal(8, std, N),
    'width': np.random.normal(25, std, N),
    'weight': np.random.normal(1000,std,N)}
)

baloon = pd.DataFrame({
    'length': np.random.normal(6, std, N),
    'width': np.random.normal(6, std, N),
    'weight': np.random.normal(4,std,N)}
)

fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.array([width, length, weight]).T

Y = np.concatenate((Melons_label, Balloons_label))

ax.scatter(X[0:N, 0], X[0:N, 1], X[0:N, 2], c='green', label='Melon')
ax.scatter(X[N: , 0], X[N: , 1], X[N: , 2], c='blue', label='Baloon')

ax.set_xlabel('Width')
ax.set_ylabel('Length')
ax.set_zlabel('Weight')
ax.set_title('3D_Figure')   
plt.show()
# Out:
# c:\users\amin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
